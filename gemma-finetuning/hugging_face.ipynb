# %%
from transformers import pipeline

pipe = pipeline("text-generation", model="google/gemma-4-E2B", device_map="auto")

# The raw base model will simply complete the sentence
prompt = "The process of photosynthesis in plants involves"
output = pipe(prompt, max_new_tokens=50, num_return_sequences=1)

print(output[0]['generated_text'])
# Out:
# Loading weights:   0%|          | 0/1951 [00:00<?, ?it/s]
# [transformers] Both `max_new_tokens` (=50) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The process of photosynthesis in plants involves several steps that occur in different locations within the cell. The correct order of the steps in photosynthesis is:
#
# 1. <strong>Light Reactions</strong>: These occur in the thylakoid membranes of the chloroplasts. Light energy from sunlight is captured
